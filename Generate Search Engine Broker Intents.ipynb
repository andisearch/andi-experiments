# %% [markdown]
# # Experiments Creating Search Intent Sample Utterances

# %% [markdown]
# Some example scripts and experiments to generate sample utterances sources including stackoverflow top questions, top google keyword searches, Wolfram|Alpha example queries, popular pages on Wikipedia.

# %% [markdown]
# # Google Search Intents

# %%
# import the wolfram intents
import os, json, sys, re
path_to_json = "intents-exports/"
with open(os.path.join(path_to_json, "wolfram_simple_utterances.json")) as wa_simple_file:
    wa_simple = json.load(wa_simple_file)
with open(os.path.join(path_to_json, "wolfram_complex_utterances.json")) as wa_complex_file:
    wa_complex = json.load(wa_complex_file)

# %% [markdown]
# # DDG Instant Answer Intents
#
# Determine queries that are entities/categories suitable for wiki/ddg

# %%
import requests
response = ''
def search_ddg(query):
    ddg_url = "https://duckduckgo-duckduckgo-zero-click-info.p.rapidapi.com/"

    ddg_querystring = {"q":query,"no_redirect":"1","no_html":"1","skip_disambig":"1","format":"json"}

    ddg_headers = {
        'x-rapidapi-key': "** key here ***",
        'x-rapidapi-host': "duckduckgo-duckduckgo-zero-click-info.p.rapidapi.com"
        }

    try:
        ddg_response = json.loads(requests.request("GET", ddg_url, headers=ddg_headers, params=ddg_querystring).text)
    except: 
        return ''
    if 'AbstractText' in ddg_response:
        response = ddg_response["AbstractText"]
    else:
        response = ''
    return response

# %%
wa_simple_ddg = []
for query in wa_simple["simple"]:
    ddg_result = search_ddg(query)
    print(query + ":\n" + ddg_result)
    if ddg_result:
        wa_simple_ddg.append(query)
for query in wa_complex["complex"]:
    ddg_result = search_ddg(query)
    print(query + ":\n" + ddg_result)
    if ddg_result:
        wa_simple_ddg.append(query) 
wa_simple_ddg

# %%
len(wa_simple_ddg)

# %%
# Check if is entity using spacy
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
def get_entities(text):
    doc = nlp(text)
    ent_list = []
    for ent in doc.ents:
        ent_list.append(ent.text)
    return ent_list

for query in wa_complex["complex"]:
    entities = get_entities(query)
    #print(entities)
    if len(entities) == 1 and query == entities:
        print(query + ":\n" + str(entities))

# %%
get_entities("horse")

# %%
# Create filtered list of Wolfram simple and complex intents without entities samples
wa_simple_filtered = []
wa_complex_filtered = []
for i in wa_simple["simple"]:
    if i not in wa_simple_ddg:
        wa_simple_filtered.append(i)
for i in wa_complex["complex"]:
    if i not in wa_simple_ddg:
        wa_complex_filtered.append(i)

# %%
# Save utterances for wolfram simple and complex intents

# Save the simple utterances with answers to a file
lex_utterances_file = open("wolfram_simple_utterances_filtered.txt", "w")
lex_utterances_file.write(str(wa_simple_filtered).replace("', '", "\",\n    \"").replace("', \"", "\",\n    \"").replace("\", '","\",\n    \"").replace("['", "[\"").replace("']", "\"]"))
lex_utterances_file.close()

# Save the complex utterances with answers to a file
lex_utterances_file = open("wolfram_complex_utterances_filtered.txt", "w")
lex_utterances_file.write(str(wa_complex_filtered).replace("', '", "\",\n    \"").replace("', \"", "\",\n    \"").replace("\", '","\",\n    \"").replace("['", "[\"").replace("']", "\"]"))
lex_utterances_file.close()

# Save the DDG intents for entities with answers to a file
# Save the simple utterances with answers to a file
ddg_utterances_file = open("ddg_utterances.txt", "w")
ddg_utterances_file.write(str(wa_simple_ddg).replace("', '", "\",\n    \"").replace("', \"", "\",\n    \"").replace("\", '","\",\n    \"").replace("['", "[\"").replace("']", "\"]"))
ddg_utterances_file.close()

# %% [markdown]
# ## Create Google Questions Intent

# %%
path_to_json = "intents-exports/"
with open(os.path.join(path_to_json, "google_questions_combined_deduped.json")) as google_questions_file:
    google_questions = json.load(google_questions_file)

# %%
questions_list = google_questions["questions"]

# %%
punctuations = '''‐_+=|!()[]{};:’"\,<>/?@#$%^&*~–0123456789-.'''
deduped_google = []
for i in questions_list:
    if i not in deduped_google:
        for x in i.lower():
            if x in punctuations:
                # utterance = utterance.replace(x," ").strip()
                i = ""
        if 'what time is it' in i.lower() or 'what is the weather' in i.lower():
            i = ""
        deduped_google.append(i)

# %%
len(google_questions["questions"])

# %%
len(deduped_google)
google_questions_final = deduped_google

# %%
# Save the simple utterances with answers to a file
goog_utterances_file = open("google_questions.json", "w")
goog_utterances_file.write(str(google_questions_final).replace("', '", "\",\n    \"").replace("', \"", "\",\n    \"").replace("\", '","\",\n    \"").replace("['", "[\"").replace("']", "\"]"))
goog_utterances_file.close()

# %% [markdown]
# ## Create Google top queries intent

# %%
path_to_json = "intents-exports/"
with open(os.path.join(path_to_json, "google_top_queries.json")) as google_questions_file:
    google_questions = json.load(google_questions_file)
queries_list = google_questions["queries"]
punctuations = '''�‐_+=|!()[]{};:’"\,<>/?@#$%^&*~–0123456789-.'''
deduped_google = []
for i in queries_list:
    if i not in deduped_google and i not in wa_simple_filtered and i not in wa_complex_filtered and i not in wa_simple_ddg:
        for x in i.lower():
            if x in punctuations:
                # utterance = utterance.replace(x," ").strip()
                i = ""
        if 'what time is it' in i.lower() or 'what is the weather' in i.lower():
            i = ""
        deduped_google.append(i)

# %%
# Remove any items that resolve with DDG Instant Answers (entities)
google_not_ddg = []
for query in deduped_google:
    ddg_result = search_ddg(query)
    print(query + ":\n" + ddg_result)
    if not ddg_result:
        google_not_ddg.append(query)
google_queries_final = google_not_ddg

# %%
len(google_queries_final)
for idx, i in enumerate(google_queries_final):
    #print(i)
    if i == "":
        del google_queries_final[idx]
len(google_queries_final)

# %%
'''for query in deduped_google:
    entities = get_entities(query)
    #print(entities)
    if len(entities) == 1 and query == entities:
        print(query + ":\n" + str(entities))'''

# %%
# Save the simple utterances with answers to a file
goog_queries_utterances_file = open("google_queries_utterances.json", "w")
goog_queries_utterances_file.write(str(google_queries_final).replace("', '", "\",\n    \"").replace("', \"", "\",\n    \"").replace("\", '","\",\n    \"").replace("['", "[\"").replace("']", "\"]"))
goog_queries_utterances_file.close()

# %% [markdown]
# ## Create Wikipedia Intents

# %%
path_to_json = "intents-exports/"
with open(os.path.join(path_to_json, "wikipedia_top1500.json")) as wiki_file:
    wiki_pages = json.load(wiki_file)
pages_list = wiki_pages["pages"]
punctuations = '''�‐_+=|!()[]{};:’"\,<>/?@#$%^&*~–0123456789-.'''
deduped_wiki = []
for i in pages_list:
    if i not in deduped_wiki and i not in deduped_google and i not in wa_simple_filtered and i not in wa_complex_filtered and i not in wa_simple_ddg and i not in google_queries_final and i != "":
        for x in i.lower():
            if x in punctuations:
                # utterance = utterance.replace(x," ").strip()
                i = ""
        if 'what time is it' in i.lower() or 'what is the weather' in i.lower():
            i = ""
        if i != "":
            deduped_wiki.append(i)

# %%
len(deduped_wiki)

# %%
# Save the simple utterances with answers to a file
wiki_queries_utterances_file = open("wiki_utterances.json", "w")
wiki_queries_utterances_file.write(str(deduped_wiki).replace("', '", "\",\n    \"").replace("', \"", "\",\n    \"").replace("\", '","\",\n    \"").replace("['", "[\"").replace("']", "\"]"))
wiki_queries_utterances_file.close()

# %% [markdown]
# # Generate Website Name and Domain Slots for searching

# %%
from bang_data import NAV_DATA
# website names
searchable_names = []
searchable_domains = []
punctuations = '''�‐_+=|!()[]{};:’"\,<>/?@#$%^&*~–0123456789-.'''
domain_punctuations = '''�‐_+=|!()[]{};:’"\,<>/?@#$%^&*~–'''
for site in NAV_DATA:
    if '{{{s}}}' in site['u'] and site['d'] != '' and not 'duckduckgo' in site['u']:
        # searchable website
        site_name = site['s'].lower()
        #site_domain_clean = site['d'].lower().replace('www.', '').replace('.', ' ')
        site_domain = site['d'].lower().replace('www.', '')
        for x in site_name:
            if x in punctuations:
                # utterance = utterance.replace(x," ").strip()
                site_name = ''
        for x in site_domain:
            if x in domain_punctuations:
                site_domain = ''
        if site_name != '' and site_name not in searchable_names:
            searchable_names.append(site_name)
        if site_domain != '' and site_domain not in searchable_domains:
            searchable_domains.append(site_domain)
# Generate objects
names_slots = []
domains_slots = []
for name in searchable_names:
    item = {'value': name}
    names_slots.append(item)
for domain in searchable_domains:
    item = {'value': domain}
    domains_slots.append(item)

# %%
import json
with open("search_names_slots.json", "w") as fp:
    json.dump(names_slots, fp)
with open("search_domains_slots.json", "w") as fp:
    json.dump(domains_slots, fp)

# %% [markdown]
# # Generate knowledge slots
#
# Generates a list of slot objects with the top 1500 wikipedia pages to use for detecting Knowledge queries

# %%
import os
import json
path_to_json = "intents-exports/"
with open(os.path.join(path_to_json, "wikipedia_top1500.json")) as wiki_file:
    wiki_pages = json.load(wiki_file)
pages_list = wiki_pages["pages"]
punctuations = '''�‐_+=|!()[]{};:’"\,<>/?@#$%^&*~–0123456789-.'''
deduped_wiki = []
for i in pages_list:
    if i not in deduped_wiki and i != "":
        for x in i.lower():
            if x in punctuations:
                # utterance = utterance.replace(x," ").strip()
                i = ""
        if 'what time is it' in i.lower() or 'what is the weather' in i.lower():
            i = ""
        if i != "":
            deduped_wiki.append(i)
wiki_phrases = []
for wiki_phrase in deduped_wiki:
    item = {'value': wiki_phrase}
    wiki_phrases.append(item)

# %%
import json
with open("wiki_phrase_slots.json", "w") as fp:
    json.dump(wiki_phrases, fp)

# %% [markdown]
# # Programming Slot Types and Intent

# %%
import json
import requests
import tldextract
import urllib
import socket
import os
from bs4 import BeautifulSoup
path_to_json = "intents-exports/"

# %%
# Stackoverflow Top Questions
url_base = 'https://stackoverflow.com/questions?tab=votes&page='
pages = 10
question_list = []
platforms = ['']
for page in range(pages):
    url = f"{url_base}{page}"
    r = requests.get(url)
    html = BeautifulSoup(r.content, 'html.parser')
    questions_containers = html.findAll('div', class_="question-summary")
    
    for question_link in questions_containers:
        question = question_link.find('a').get_text(' ').lower()
        
        question_list.append(question)
question_list

# %%
platforms = ['python', 'javascript', 'java','swift ', ' c ', 'ruby', 'vb net', 'perl', 'htaccess', 'assembly', 'jquery', 'smalltalk', 'react ', 'react native', 'basic ', ' c# ', ' c++ ', ' f# ', 'haskell', ' r ', ' rust ', 'angular', ' vue ', 'vue js', 'json', ' git ', 'git ', ' git','html', 'actionscript', 'php', 'css', 'sql server', 'sqllite', ' sql ', 'android', 'ios ', 'mysql', 'powershell', 'maven', 'pandas', 'windows', 'github', 'vagrant', 'docker ', 'junit', 'microsoft', 'mac ', 'angularjs', 'npm ', 'bower ', 'browserify ', 'gulp ', 'grunt ', 'webpack', 'postgresql', 'excel ', 'eclipse ', 'macos', 'dockerfile', 'linux']
remove = ['youtube']

# %%
punctuations = '''�‐_+=|!()[]{};:’”"\,<>/?@#$%^&*~–0123456789-—.“””…'''
deduped_questions = []
for i in question_list:
    
    if i not in deduped_questions and i != "":
        i = i.lower()
        for platform in platforms:
            if 'Platform' in i:
                #print("Platform already in:", i)
                break
            else:
                i = i.replace(platform, ' Platform ', 1)
        for x in i.lower():
            if x in punctuations:
                i = i.replace(x," ").strip()
                #i = ""
            if x in ["'"]:
                i = ""
        if 'what time is it' in i.lower() or 'what is the weather' in i.lower():
            i = ""
        for remover in remove:
            if remover in i:
                i = ""
        i = i.replace("Platform", "{Platform}")
        i = " ".join(i.split())
        if i != "" and not i in deduped_questions:
            deduped_questions.append(i)

# %%
deduped_questions
# Out:
# ['why is processing a sorted array faster than processing an unsorted array',
#  'how do i undo the most recent local commits in {Platform}',
#  'how do i delete a {Platform} branch locally and remotely',
#  'what does the yield keyword do',
#  'what is the correct {Platform} content type',
#  'what is the operator in c',
#  'how do i rename a local {Platform} branch',
#  'how can i remove a specific item from an array',
#  'what and where are the stack and heap',
#  'can comments be used in {Platform}',
#  'how do i check if an element is hidden in {Platform}',
#  'why does {Platform} think chucknorris is a color',
#  'what does use strict do in {Platform} and what is the reasoning behind it',
#  'how do i redirect to another webpage',
#  'how do i force {Platform} pull to overwrite local files',
#  'how to modify existing unpushed commit messages',
#  'how do {Platform} closures work',
#  'how do i revert a {Platform} repository to a previous commit',
#  'how to check whether a string contains a substring in {Platform}',
#  'how to remove local untracked files from the current {Platform} working tree',
#  'how do i check out a remote {Platform} branch',
#  'var functionname function vs function functionname',
#  'why is subtracting these two times in giving a strange result',
#  'is {Platform} pass by reference or pass by value',
#  'what is the difference between string and string in c',
#  'what does if name main do',
#  'does {Platform} have a ternary conditional operator',
#  'how do i remove a property from a {Platform} object',
#  'what are metaclasses in {Platform}',
#  'what is the difference between px dip dp and sp',
#  'how do i check whether a file exists without exceptions',
#  'how to make {Platform} forget about a file that was tracked but is now in gitignore',
#  'how do i return the response from an asynchronous call',
#  'how do i find all files containing specific text on {Platform}',
#  'which equals operator vs should be used in {Platform} comparisons',
#  'put vs post in rest',
#  'how do i include a {Platform} file in another javascript file',
#  'the definitive guide to form based website authentication closed',
#  'how to disable text selection highlighting',
#  'how do i merge two dictionaries in a single expression in {Platform} taking union of dictionaries',
#  'move the most recent commit s to a new branch with {Platform}',
#  'how to get the source directory of a bash script from within the script itself',
#  'what is the most efficient way to deep clone an object in {Platform}',
#  'how to execute a program or call a system command from {Platform}',
#  'how do i discard unstaged changes in {Platform}',
#  'what is the maximum length of a url in different browsers',
#  'what is a plain english explanation of big o notation',
#  'how to resolve merge conflicts in {Platform} repository',
#  'for each over an array in {Platform}',
#  'what is the difference between inner join and outer join',
#  'how can i reset or revert a file to a specific revision',
#  'how do i check whether a checkbox is checked in {Platform}',
#  'how to validate an email address in {Platform}',
#  'how to replace all occurrences of a string',
#  'how to pass null a real surname to a soap web service in {Platform}',
#  'reference — what does this symbol mean in {Platform}',
#  'how do i push a new local branch to a remote {Platform} repository and track it too',
#  'how can i safely create a nested directory',
#  'how to horizontally center an element',
#  'thinking in angularjs if i have a {Platform} background closed',
#  'what is the difference between a uri a url and a urn',
#  'how can i add an empty directory to a {Platform} repository',
#  'how to create a guid uuid',
#  'how can i determine the url that a local {Platform} repository was originally cloned from',
#  'how to clone all remote branches in {Platform}',
#  'how to change the uri url for a remote {Platform} repository',
#  'setting checked for a checkbox with {Platform}',
#  'how do i read convert an inputstream into a string in {Platform}',
#  'the definitive {Platform} book guide and list',
#  'how do i check if an array includes a value in {Platform}',
#  'reset local repository branch to be just like remote repository head',
#  'how do you get a timestamp in {Platform}',
#  'why does google prepend while to their {Platform} responses',
#  'which href value should i use for {Platform} links or javascript void',
#  'avoiding nullpointerexception in {Platform}',
#  'how do i exit the vim editor',
#  'what exactly is restful programming',
#  'how do i make the first letter of a string uppercase in {Platform}',
#  'how do i update a {Platform} hub forked repository',
#  'how can i pair socks from a pile efficiently',
#  'how do you close hide the android soft keyboard using {Platform}',
#  'squash my last x commits together using {Platform}',
#  'how to enumerate an enum',
#  'how can i check if a directory exists in a bash shell script',
#  'what are the differences between a hashmap and a hashtable in {Platform}',
#  'how do i update from a select in {Platform}',
#  'how is {Platform} different from a virtual machine',
#  'how to make a flat list out of list of lists',
#  'difference between staticmethod and classmethod',
#  'how to delete a remote tag',
#  'proper use cases for {Platform} usermanager isuseragoat',
#  'create arraylist from array',
#  'how do i remove a submodule',
#  'how do i generate random integers within a specific range in {Platform}',
#  'understanding slice notation',
#  'make an existing {Platform} branch track a remote branch',
#  'how do i copy to the clipboard in {Platform}',
#  'grep a file but show several surrounding lines',
#  'why is char preferred over string for passwords',
#  'how do i test for an empty {Platform} object',
#  'iterate through a hashmap duplicate',
#  'how to validate an email address using a regular expression',
#  'how do i efficiently iterate over each entry in a {Platform} map',
#  'finding the index of an item in a list',
#  'how do i list all files of a directory',
#  'delete commits from a branch in {Platform}',
#  'why is the {Platform} emulator so slow how can we speed up the android emulator closed',
#  'set cellpadding and cellspacing in {Platform}',
#  'how do i tell if a regular file does not exist in bash',
#  'how do i sort a dictionary by value',
#  'what are the differences between a pointer variable and a reference variable in c',
#  'is there a {Platform} parent selector',
#  'undoing a {Platform} rebase',
#  'how can i cast int to enum',
#  'how can i create a memory leak in {Platform}',
#  'loop through an array in {Platform}',
#  '{Platform} js service vs provider vs factory',
#  'what is the not not operator in {Platform}',
#  'how do i clone a specific {Platform} branch duplicate',
#  'move existing uncommitted work to a new branch in {Platform}',
#  'what is the difference between public protected package private and private in {Platform}',
#  'using global variables in a function',
#  'how do you create a remote {Platform} branch',
#  'view the change history of a file using {Platform} versioning',
#  'how do i correctly clone a {Platform} object',
#  'when to use linkedlist over arraylist in {Platform}',
#  'how do i check if a list is empty',
#  'stash only one file out of multiple files that have changed with {Platform}',
#  'how to insert an item into an array at a specific index {Platform}',
#  'checking if a key exists in a {Platform} object',
#  'remove a file from a {Platform} repository without deleting it from the local filesystem',
#  'how can i pretty print {Platform} in a shell script',
#  'is floating point math broken',
#  'what is dependency injection',
#  'what is the difference between call and apply',
#  'get the current url with {Platform}',
#  'how do i convert a string to an int in {Platform}',
#  'how to get the current time in {Platform}',
#  'how do i post {Platform} data with curl',
#  'what is a serialversionuid and why should i use it',
#  'how can i check for an empty undefined null string in {Platform}',
#  'what does the explicit keyword mean',
#  'how do i iterate over the words of a string',
#  'how do i loop through or enumerate a {Platform} object',
#  'improve insert per second performance of sqlite',
#  'sort array of objects by string property value',
#  'event preventdefault vs return false',
#  'round to at most decimal places only if necessary',
#  'difference between {Platform} add a and git add',
#  'catch multiple exceptions in one line except block',
#  'how can i upload files asynchronously',
#  'forbidden vs unauthorized http responses',
#  'how to concatenate string variables in bash',
#  'how to stop edittext from gaining focus at activity startup in {Platform}',
#  'how to list all the files in a commit',
#  'detecting an undefined object property',
#  'how to check if an object is an array',
#  '{Platform} closure inside loops simple practical example',
#  'how to find and restore a deleted file in a {Platform} repository',
#  'difference between str and repr',
#  'commit only part of a file in {Platform}',
#  'how do you disable browser autocomplete on web form field input tag',
#  'is it possible to apply {Platform} to half of a character',
#  'how to append something to an array',
#  'add a column with a default value to an existing table in {Platform}',
#  'how to get the current branch name in {Platform}',
#  'initialization of an arraylist in one line',
#  'is there an exists function for {Platform}',
#  'how can i make a time delay in {Platform} duplicate',
#  'how can i add new keys to a dictionary',
#  'is there a unique {Platform} device id',
#  'how to make function decorators and chain them together',
#  'how do i test a private function or a class that has private methods fields or inner classes',
#  'how do i copy a folder from remote to local using scp closed',
#  'creating multiline strings in {Platform}',
#  'how do i disable the resizable property of a textarea',
#  'why is using namespace std considered bad practice',
#  'how can i know which radio button is selected via {Platform}',
#  'why is printing b dramatically slower than printing',
#  'how do i copy a file in {Platform}',
#  'what is the best way to iterate over a dictionary',
#  'how do i concatenate two lists in {Platform}',
#  'how to check if a string contains a substring in bash',
#  'how do i pass a variable by reference',
#  'how can i convert a string to boolean in {Platform}',
#  'how can i prevent sql injection in {Platform}',
#  'should i use the datetime or timestamp data type in {Platform}',
#  'list changes unexpectedly after assignment how do i clone or copy it to prevent this',
#  'flash cs refuses to let go',
#  'least astonishment and the mutable default argument',
#  'how do i make {Platform} use the editor of my choice for commits',
#  'how do you set clear and toggle a single bit',
#  'i ran into a merge conflict how can i abort the merge',
#  'determine installed {Platform} version',
#  'how can i get query string values in {Platform}',
#  'understanding {Platform} super with init methods duplicate',
#  'how to save an activity state using save instance state',
#  'how can i merge properties of two {Platform} objects dynamically',
#  'check if a given key already exists in a dictionary',
#  'convert bytes to a string',
#  'how do i check if a string contains a specific word',
#  'deleting an element from an array in {Platform}',
#  'storing objects in {Platform} localstorage',
#  'pretty print json using {Platform}',
#  'echo newline in bash prints literal n',
#  'what are the correct version numbers for c',
#  'when should static cast dynamic cast const cast and reinterpret cast be used',
#  'i need an unordered list without any bullets',
#  'how do i detect a click outside an element',
#  'how can i install pip on {Platform}',
#  'what is the {Platform} version of sleep',
#  'how can i check for undefined in {Platform} duplicate',
#  'what is init py for',
#  'ignore files that have already been committed to a {Platform} repository duplicate',
#  'encode url in {Platform}',
#  'what does cherry picking a commit with {Platform} mean',
#  'what does double star asterisk and star asterisk do for parameters',
#  'how do i modify the url without reloading the page',
#  'how do i pass command line arguments to a node js program',
#  'how can you find out which process is listening on a port on {Platform}',
#  'how can i refresh a page with {Platform}',
#  'can a a a ever evaluate to true',
#  'how can i create an executable jar with dependencies using {Platform}',
#  'how does database indexing work closed',
#  'length of a {Platform} object',
#  'how to change the author and committer name and e mail of multiple commits in {Platform}',
#  'how to format a {Platform} date',
#  'what is the difference between include filename and include filename',
#  'do i cast the result of malloc',
#  'add table row in {Platform}',
#  'how do i get the current date in {Platform}',
#  'how to make a great {Platform} reproducible example',
#  'how to iterate over rows in a dataframe in {Platform}',
#  'does a finally block always get executed in {Platform}',
#  'is there a standard function to check for null undefined or blank variables in {Platform}',
#  'how do you split a list into evenly sized chunks',
#  'in the shell what does mean',
#  '{Platform} refusing to merge unrelated histories on rebase',
#  'how do you clone a {Platform} repository into a specific folder',
#  'set a default parameter value for a {Platform} function',
#  '{Platform} scroll to element',
#  'comparing two branches in {Platform} duplicate',
#  'validate decimal numbers in {Platform} isnumeric',
#  '{Platform} fetch remote branch',
#  'how do i make {Platform} ignore file mode chmod changes',
#  'when to use margin vs padding in {Platform} closed',
#  'manually raising throwing an exception in {Platform}',
#  'how to modify a specified commit',
#  'how do you push a tag to a remote repository using {Platform}',
#  'how do i vertically center text with {Platform} duplicate',
#  'do a {Platform} export like svn export',
#  'how can i check if a program exists from a bash script',
#  'find the version of an installed {Platform} package',
#  'how to delete a file or folder',
#  'how do i parse a string to a float or int',
#  'how do i determine whether an array contains a particular value in {Platform}',
#  'how do i call one constructor from another in {Platform}',
#  'disable enable an input with {Platform}',
#  'how to access environment variable values',
#  'prop vs attr',
#  'get selected text from a drop down list select box using {Platform}',
#  'how do i give text or an image a transparent background using {Platform}',
#  'how do you change the size of figures drawn with matplotlib',
#  'how to print colored text to the terminal',
#  'converting string into datetime',
#  'http get with request body',
#  'deep cloning objects',
#  'how to select rows from a dataframe based on column values',
#  'homebrew install specific version of formula',
#  'how to change the commit author for one specific commit',
#  'why is in range so fast in {Platform}',
#  'what is the save option for {Platform} install',
#  'why are elementwise additions much faster in separate loops than in a combined loop',
#  'how do i get a substring of a string in {Platform}',
#  'open a url in a new tab and not a new window',
#  'getting the last element of a list',
#  'ssh permissions are too open error',
#  'how to get the children of the this selector',
#  'how can i transition height to height auto using {Platform}',
#  'how to make a div height of the browser window',
#  'extract filename and extension in bash',
#  'what is the best and safest way to merge a {Platform} branch into master',
#  'what does o log n mean exactly',
#  'catch multiple exceptions at once',
#  'how do i get a consistent byte representation of strings in {Platform} without manually specifying an encoding',
#  'what is the rule of three',
#  'vertically align text to top within a uilabel',
#  'how to upgrade all {Platform} packages with pip',
#  'how do i show the changes which have been staged',
#  'indent multiple lines quickly in vi',
#  'what is {Platform} p and why was it created',
#  'what is reflection and why is it useful',
#  'what are the {Platform} rules and idioms for operator overloading',
#  'how do i import an {Platform} file using the command line in mysql',
#  'how do i split a string on a delimiter in bash',
#  'how do i empty an array in {Platform}',
#  'how can i make a div not larger than its contents',
#  'how to decide when to use node js',
#  'what are mvp and mvc and what is the difference',
#  'how do i lowercase a string in {Platform}',
#  'what is the preferred syntax for defining enums in {Platform}',
#  'implements runnable vs extends thread in {Platform}',
#  'how to add images to readme md on {Platform} hub',
#  'showing which files have changed between two revisions',
#  'how do you parse and process {Platform} xml in php',
#  'how do i declare and initialize an array in {Platform}',
#  'how to mkdir only if a directory does not already exist',
#  'how do you display code snippets in ms word preserving format and syntax highlighting',
#  '{Platform} is it br br or br',
#  'how to {Platform} clone including submodules',
#  'difference between decimal float and double in net',
#  'how to write a switch statement in {Platform}',
#  'iterate through object properties',
#  'compare two dates with {Platform}',
#  'document ready equivalent without {Platform}',
#  '{Platform} chop slice trim off last character in string',
#  'how to update each dependency in package {Platform} to the latest version',
#  'get the size of the screen current web page and browser window',
#  'how can i select an element with multiple classes in {Platform}',
#  'should i use {Platform} or docker for creating an isolated environment closed',
#  'how to list only the file names that changed between two commits',
#  'make a div fill the height of the remaining screen space',
#  'how do i center text horizontally and vertically in a textview',
#  'how can i delete a file from a {Platform} repository',
#  'what is the copy and swap idiom',
#  'generating random whole numbers in {Platform} in a specific range',
#  'how can i recursively find all files in current and subfolders based on wildcard matching',
#  'is there a way to run {Platform} on android',
#  'what are the differences between gitignore and gitkeep',
#  'how do i sort a list of dictionaries by a value of the dictionary',
#  'what are valid values for the id attribute in {Platform}',
#  'daylight saving time and time zone best practices closed',
#  'how to retrieve the hash for the current commit in {Platform}',
#  'how to create an {Platform} button that acts like a link',
#  'how does {Platform} prototype work',
#  'how to get an enum value from a string value in {Platform}',
#  'how to replace a character by a newline in vim',
#  'how can i delete all {Platform} branches which have been merged',
#  'how do i parse command line arguments in bash',
#  'how do you assert that a certain exception is thrown in {Platform} tests',
#  'what is the scope of variables in {Platform}',
#  '{Platform} equivalent to printf string format',
#  'renaming columns in {Platform}',
#  'how do i revert all local changes in {Platform} managed project to previous state',
#  'finding duplicate values in a {Platform} table',
#  'when to use self over this',
#  'how do i generate a random int number',
#  'are static class variables possible in {Platform}',
#  'how can i remove a key from a {Platform} dictionary',
#  'how do i format a microsoft {Platform} date',
#  'vertically align text next to an image',
#  'what does the operator do in c',
#  'how to change the cursor into a hand when a user hovers over a list item',
#  'when should i use double or single quotes in {Platform}',
#  'find and kill process locking port on mac',
#  '{Platform} says execution of scripts is disabled on this system',
#  'how to read a file line by line into a list',
#  'how to concatenate text from multiple rows into a single text string in {Platform}',
#  'what is so bad about singletons closed',
#  'how do i get the number of elements in a list',
#  'generate random string characters in {Platform}',
#  'what is the best way to give a {Platform} auto property an initial value',
#  'vim clear last search highlighting',
#  'how to print without newline or space',
#  'how can i symlink a file in {Platform} closed',
#  'download a specific tag with {Platform}',
#  'how to format numbers as currency string',
#  'c introduced a standardized memory model what does it mean and how is it going to affect {Platform} programming',
#  'how to print a number with commas as thousands separators in {Platform}',
#  'how does data binding work in {Platform} js',
#  'how to use {Platform} net urlconnection to fire and handle http requests',
#  'how to lazy load images in listview in {Platform}',
#  'how to exit in node js',
#  'easy way to pull latest of all {Platform} submodules',
#  '{Platform} vs bower vs browserify vs gulp vs grunt vs webpack',
#  '{Platform} show tables in postgresql',
#  'check if a variable is a string in {Platform}',
#  'how to change the output color of echo in {Platform}',
#  'how do i create an excel xls and xlsx file in {Platform} without installing microsoft office',
#  'branch from a previous commit using {Platform}',
#  'generate random number between two numbers in {Platform}',
#  'what is the optimal algorithm for the game',
#  'get int value from enum in c',
#  'docker copying files from {Platform} container to host',
#  'what is inversion of control',
#  'why is reading lines from stdin much slower in c than {Platform}',
#  '{Platform} check if variable exists is defined initialized',
#  'get selected value in dropdown list using {Platform}',
#  'how to check if a column exists in a {Platform} table',
#  'debug certificate expired error in eclipse {Platform} plugins',
#  'is there a way to cache {Platform} hub credentials for pushing commits',
#  'what is a non capturing group in regular expressions',
#  'get current url with {Platform}',
#  'what is a {Platform} bean exactly',
#  'how can i profile {Platform} code running on linux',
#  'how to delete from a text file all lines that contain a specific string',
#  '{Platform} describe table',
#  'how to change permissions for a folder and its subfolders files in one step',
#  'what is a smart pointer and when should i use one',
#  'what is the difference between cmd and entrypoint in a {Platform}',
#  'how do {Platform} triangles work',
#  'calling a function of a module by using its name a string',
#  'why can templates only be implemented in the header file',
#  '{Platform} is not working after macos update xcrun error invalid active developer path library developer commandlinetools',
#  'why is using for in for array iteration a bad idea',
#  'how to recover a dropped stash in {Platform}',
#  'how do i break out of nested loops in {Platform}',
#  'how to get screen dimensions as pixels in {Platform}',
#  'abort ajax requests using {Platform}',
#  'what is the purpose of phony in a makefile',
#  'what is a nullreferenceexception and how do i fix it',
#  'make gitignore ignore everything except a few files',
#  'viewing unpushed {Platform} commits',
#  'how to randomly select an item from a list',
#  'determine the type of an object',
#  'how to return only the date from a {Platform} datetime datatype']

# %%
# Save the simple utterances with answers to a file
programming_utterances_file = open("programming_utterances.json", "w")
programming_utterances_file.write(str(deduped_questions).replace("', '", "\",\n    \"").replace("', \"", "\",\n    \"").replace("\", '","\",\n    \"").replace("['", "[\"").replace("']", "\"]"))
programming_utterances_file.close()
